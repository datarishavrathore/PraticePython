# %%
n=45
b=67
temp=n
n=b
b=temp
print(f"this is greater{n} and this is lower{b}")
# Out:
# this is greater67 and this is lower45

# %%
name="python is a good lanuage 'and' writeen in code"
print(name)
# Out:
# python is a good lanuage 'and' writeen in code

# %%
a=int(input("enter the num="))
b=int(input("enter the num2="))
res=a+b
print(f"this ia {a} number and this is {b} number:{res}")
# Out:
# enter the num= 4
# enter the num2= 8
# this ia 4 number and this is 8 number:12

# %%
a=input("enter name=")
if a=="rishav":
    print("ok")
else:
    print("bye")
# Out:
# enter name= sdfghj
# bye

# %%
<,>,>=,<=,==,!=)

# %%
num=int(input("enter the num="))
if num>=30:
    print("ok")
else:
    print("bye")
# Out:
# enter the num= 30
# ok

# %%
num=int(input("enter the num="))
if num<=30:
    print(f"lower hai {num} yeh")
else:
    print("bye")
# Out:
# enter the num= 31
# bye

# %%
name=input("enter the name=")
if name!="rishav":
    print("galat hai name")
else:
    print(f"this {name}")
# Out:
# enter the name= rishav
# this rishav

# %%
#Logical Operator (and, or , not )
marks=int(input("enter marks"))
if not (marks>=30):
    print("bye")
else:
    print("ok")
# Out:
# enter marks 31
# ok

# %%
#Switch values of two integers
a=98
b=97
temp=a
a=b
b=temp
print(a,b)
# Out:
# 97 98

# %%
#Switch values of two strings (characters) 
a="java"
b="python"
var=a
a=b
b=var

print(a,b)
# Out:
# python java

# %%
#Update balance after deposit 
a=int(input("enter your current balance="))
b=int(input("enter your deposit balance="))
c=a+b
print(c)
# Out:
# enter your current balance= 300
# enter your deposit balance= 200
# 500

# %%
#Update balance after withdrawal
a=int(input("enter your current balance="))
b=int(input("enter your withdrawal balance="))
c=a-b
print(c)
# Out:
# enter your current balance= 300
# enter your withdrawal balance= 100
# 200

# %%
#Increase shopping cart items by 3 
a=int(input("enter cart items values"))
c=a+3
print(c)
# Out:
# enter cart items values 300
# 303

# %%
#Apply a 20% discount to a price
a=int(input("enter the price"))
b=int(input("enter the discount="))
discount=a*b/100
final=a-discount
print(final)
# Out:
# enter the price 20000
# enter the discount= 20
# 16000.0

# %%
#Calculate student percentage
#Percentage = (Obtained Marks / Total Marks) × 100
marks=int(input("enter the marks"))
percent=(marks / 500)*100
print(percent)
# Out:
# enter the marks 450
# 90.0

# %%
#average = (a + b + c) / 3
sub1=int(input("enter the marks sub1"))
sub2=int(input("enter the marks sub2"))
sub3=int(input("enter the marks sub3"))
sub4=int(input("enter the marks sub4"))
avg=(sub1+sub2+sub3+sub4)/4
print(avg)
# Out:
# enter the marks sub1 23
# enter the marks sub2 34
# enter the marks sub3 56
# enter the marks sub4 67
# 45.0

# %%
#Calculate average of 3 numbers 
sub1=int(input("enter the marks sub1"))
sub2=int(input("enter the marks sub2"))
sub3=int(input("enter the marks sub3"))
avg=(sub1+sub2+sub3)/3
print(avg)
# Out:
# enter the marks sub1 34
# enter the marks sub2 45
# enter the marks sub3 34
# 37.666666666666664

# %%
#Calculate profit or loss percentage 
num=int(input("enter your profit="))
num2=int(input("enter your loss="))
percent=(num/ num2)*100
print(percent)
# Out:
# enter your profit= 300
# enter your loss= 200
# 66.66666666666666

# %%
num=int(input("enter your profit="))
num2=int(input("enter your loss="))
percent=(num2/ num)*100
print(percent)
# Out:
# enter your profit= 300
# enter your loss= 200
# 66.66666666666666

# %%
# Calculate simple interest SI = (10000 × 5 × 2) / 100
principal=int(input("enter the princiapla"))
rate=int(input("enter the rate="))
time=int(input("enter the time"))
SI=(principal*5*2)/100
print(SI)
# Out:
# enter the princiapla 100
# enter the rate= 2
# enter the time 1
# 10.0

# %%
#amount = p * (1 + r / 100) ** t
p=int(input("enter the princiapla"))
r=int(input("enter the rate="))
t=int(input("enter the time"))
SI=p*(1+r/100)**t
print(SI)
# Out:
# enter the princiapla 3000
# enter the rate= 20
# enter the time 1
# 3600.0

# %%
#Calculate tax on income
income=int(input("enter the income="))
tax=int(input("enter the tax="))
var=(income*tax)/100
print(var)
# Out:
# enter the income= 4000
# enter the tax= 20
# 800.0

# %%
#increase = ((new_value - old_value) / old_value) * 100
iv=int(input("enter your value"))
fv=int(input("enter the final value="))
temp=((iv-fv)/iv)*100
print(temp)
# Out:
# enter your value 4000
# enter the final value= 300
# 92.5

# %%
cp=int(input("enter the cost price="))
sp=int(input("enter the sp="))
if cp>sp:
    profit=cp-sp
    profit_percent=(profit/cp)*100
    print(profit_percent)
elif cp>sp:
    loss=cp-sp
    loss_per=(loss/cp)*100
    print(loss_per)
else:
    print("thank you")
# Out:
# enter the cost price= 1000
# enter the sp= 300
# 70.0

# %%
p1=int(input("enter the run score player1="))
p2=int(input("enter the run score player2="))
p3=int(input("enter the run score player3="))
p4=int(input("enter the run score player4="))
p5=int(input("enter the run score player5="))
num=p1+p2+p3+p4+p5
avg=(p1+p2+p3+p4+p5)/5
print(f"total runs {num} and player avgerage" ,avg)
# Out:
# enter the run score player1= 34
# enter the run score player2= 234
# enter the run score player3= 24
# enter the run score player4= 34
# enter the run score player5= 56
# total runs 382 and player avgerage 76.4

# %%
age=int(input("enter the your age="))
total=65
if age<=65:
    year_left=65-age
    print(f"you have completed {age} you have still age",year_left)
elif age>=65:
    years_left=65-age
    print(f" you have reached your retrirement age {age}")
else:
    print("welcome")
# Out:
# enter the your age= 34
# you have completed 34 you have still age 31

# %%
#area = 3.14 * radius * radius
#Area = π * radius^2.
radius=float(input("enter the radius of circle="))
area=3.14 * radius*radius
print(area)
# Out:
# enter the radius of circle= 45
# 6358.500000000001

# %%
ns=int(input("enter your net salary="))
bonus=int(input("enter the bonus="))
oc=int(input("enter the oc="))
tax=(ns+bonus+oc)/10
print(tax)
# Out:
# enter your net salary= 30000
# enter the bonus= 5000
# enter the oc= 2000
# 3700.0

# %%
age=int(input("enter your age for loan="))
if age>=18 and age <=60:
    
    
    print("f Valid age for loan")
    monthly_income=int(input("enter your monthly income="))
    
    if monthly_income>=25000:
        print("Your {monthly_income} is good for loan")
    else:
        print("Your monthly income is lower")

    credit_score=int(input("enter your credit score"))

    if credit_score>=700:
        print("Your Crdit Score is good")
    else:
        print("Your Credit Score is low")

    debt=int(input("ebter your debt="))
        if debt<=10000:
                print("You are debt is good")
            else:
                print("you debt is more")

else:
    print("Age nhi hai")
# Out:
# enter your age for loan= 19
# f Valid age for loan
# enter your monthly income= 30000
# Your {monthly_income} is good for loan

# %%
exp=int(input("enter the employee exp="))
salary=80000
bonus=5000
sum=salary+bonus
if exp<=10:
    print("Senior Employee")
    print(f"Your base salary {salary}")
elif exp>=11:
    print(f"you are senior employee receive {bonus} total bonus and salary ",sum)
    
else:
    print("junior")
# Out:
# enter the employee exp= 12
# you are senior employee receive 5000 total bonus and salary  85000

# %%
days=int(input("enter the book borrowed days="))
if days<=5:
    print("You are charge for 2 rupees")
elif days>=6 and <=10:
    print("you are charge for 3 rupees=")
elif days=>=11 and <=15:
    print("You are charge for 4 rupees)
elif days>=16:

# %%
a=45.6
b=int(a)
print(b)
# Out:
# 45

# %%
# Find the length of the text python and convert the value to float and convert it to string
a="python"
rev=0
for i in range(len(a)):
    rev +=1
rev=float(rev)
rev=str(rev)
print(rev)
# Out:
# 6.0

# %%
# Check if the floor division of 7 by 3 is equal to the int converted value of 2.7.
a=7
b=3
c=a//b
z=float(c)
print(z)
# Out:
# 2.0

# %%
# Check if type of '10' is equal to type of 10
a="10"
b=10
if type(a)==type(b):
    print("ok")
else:
    print("bye")
# Out:
# bye

# %%
# Check if int('9.8') is equal to 10
a=9.8
b=10
if a==b:
    print("yes")
else:
    print("No")
# Out:
# No

# %%
# Write a script that prompts the user to enter hours and rate per hour. Calculate pay of the person?
a=int(input("enter the hours="))
b=int(input("enter the rate per hour="))
z=a*b
print(z)
# Out:
# enter the hours= 3
# enter the rate per hour= 780
# 2340

# %%
# Write a script that prompts the user to enter number of years. Calculate the number of seconds a person can live. Assume a person can live hundred years
years=int(input("enter the your years="))
second=60
live=years * 365 * 24 * 60 * 60
print(live)
# Out:
# enter the your years= 26
# 819936000

# %%
#count:vowel
#count constants
#sum of index
string = "python programming"
i=0
size=len(string)
count_vowel=0
while i<size:
    if string[i] in "aeiouAEIOU":
        count_vowel+=1
    i+=1
    print(f"Total Vowels: {count_vowel}",end=" ")

# %%
#count constants
string = "python programming"
i=0
size=len(string)
count_vowel=0
while i<size:
    if string[i] not in "aeiouAEIOU":
        count_vowel+=1
    i+=1
    print(f"Total Vowels: {count_vowel}",end=" ")

# %%
for i in range(5):
    for j in range(5):
        if j == 0 or j == 4 or i == 2:
            print("*", end=" ")
        else:
            print(" ", end=" ")
    print()

# %%
print("hello world")
print()
print("bye")
# Out:
# hello world
#
# bye

# %%
# # Let's convert the integer number 6 to a string and a float
a=6
print(str(a))
print(float(a))
print(bool(a))
# Out:
# 6
# 6.0
# True

# %%
# Let's conver the float number 3.14 to a string and an integer
a=3.1
print(str(a))
print(int(a))
print(bool(a))
# Out:
# 3.1
# 3
# True

# %%
# Expereson and varables
x=5+8+8+6+4+67+89+23+78+2
print(x)
print(type(x))
# Out:
# 290
# <class 'int'>

# %%
x=5/8/8/6/4/67/89/23/78/2
print(x)
print(type(x))
# Out:
# 1.5214635240118474e-10
# <class 'float'>

# %%
# Floor division
a=56//34//46
print(a)
print(type(a))
# Out:
# 0
# <class 'int'>

# %%
# Modulus
a=56%6
print(a)
print(type(a))
# Out:
# 2
# <class 'int'>

# %%
# Exponentation
a=56**3
print(a)
print(type(a))
# Out:
# 175616
# <class 'int'>

# %%
# An example: Let's calculate how many minutes there are in 20 hours?
hour=20
minute=60
time=hour*minute
print(time)
# Out:
# 1200

# %%
# An example: Let's calculate how many hours there are in 348 minutes?

minutes=348
hour=60
time=348/60
print(time)
# Out:
# 5.8

# %%
# Mathematican expression
x=23+5*6
y=(8+6)*45
print(x+y)
print(x*y)
print(x**y)
print(x/y)
print(x//y)
print(x%y)
# Out:
# 683
# 33390
# ...
# 0.08412698412698413
# 0
# 53

# %%
# Varables
number=89
print(number)
print(type(number))

x=67
y=67
z=x*y
z=x+y
print(z)
# Out:
# 89
# <class 'int'>
# 134

# %%
# the values of x, y, and z can be wri en in one line. 
a,b,c=3,4,6
print(a+b+c)
print(a*b*c)
print(a/b/c)
print(a//b//c)
# Out:
# 13
# 72
# 0.125
# 0

# %%
a="rishav"
print(type(a))
# Out:
# <class 'str'>

# %%
# Digitals and spaces in a string
'4,6,35,36,24, 6'
# Out:
# '4,6,35,36,24, 6'

# %%
# Specific characters in a string
'@,$#,^,&,*,<,>,'
# Out:
# '@,$#,^,&,*,<,>,'

# %%
num=int(input("enter the marks"))
if num<30:
    print("fail")
elif num>=31 and num<=50:
    print("2nd")

else:
    print("Fail")
# Out:
# enter the marks 34
# 2nd
